# %%
import os, subprocess
import json
import uproot3
import awkward as ak
import numpy as np
from coffea import processor, util, hist
import pandas as pd

from plotter import *

# %%
lumis = {}
lumis['2016'] = 35.9
lumis['2017'] = 41.5
lumis['2018'] = 59.9

with open('xsec.json') as f:
  xs = json.load(f)

with open('pmap.json') as f:
  pmap = json.load(f)

# %%
year = '2017'
nfiles = len(subprocess.getoutput("ls infiles-split/"+year+"*.json").split())
outsum = processor.dict_accumulator()

# %%
repickle=True

# Load all files - this takes a while
if repickle:
    nfiles = len(subprocess.getoutput("ls infiles-split/"+year+"*.json").split())
    for n in range(1,nfiles+1):

        with open('infiles-split/'+year+'_'+str(n)+'.json') as f:
            infiles = json.load(f)
    
        filename = '/myeosdir/vbf-category/outfiles/'+year+'_'+str(n)+'.coffea'
        if os.path.isfile(filename):
            out = util.load(filename)
            outsum.add(out)
            print('Loaded file '+str(n))
        else:
            print('Missing file '+str(n),infiles.keys())
            #print("File " + filename + " is missing")
        
    scale_lumi = {k: xs[k] * 1000 *lumis[year] / w for k, w in outsum['sumw'].items()}
    outsum['muonkin'].scale(scale_lumi, 'dataset')
    outsum['mujetkin'].scale(scale_lumi, 'dataset')
    muonkin = outsum['muonkin'].group('dataset', hist.Cat('process', 'Process'), pmap)
    mujetkin = outsum['mujetkin'].group('dataset', hist.Cat('process', 'Process'), pmap)

    outfile = open('pickles/'+str(year)+'_muonkin.pkl', 'wb')
    pickle.dump(muonkin, outfile, protocol=-1)
    outfile.close()
    
    outfile = open('pickles/'+str(year)+'_mujetkin.pkl', 'wb')
    pickle.dump(mujetkin, outfile, protocol=-1)
    outfile.close()
# Out:
# Loaded file 1
# Loaded file 2
# Loaded file 3
# Loaded file 4
# Loaded file 5
# Loaded file 6
# Loaded file 7
# Loaded file 8
# Loaded file 9
# Loaded file 10
# Loaded file 11
# Loaded file 12
# Loaded file 13
# Loaded file 14
# Loaded file 15
# Loaded file 16
# Loaded file 17
# Loaded file 18
# Loaded file 19
# Loaded file 20
# Loaded file 21
# Loaded file 22
# Loaded file 23
# Loaded file 24
# Loaded file 25
# Loaded file 26
# Loaded file 27
# Loaded file 28
# Loaded file 29
# Loaded file 30
# Loaded file 31
# Loaded file 32
# Loaded file 33
# Loaded file 34
# Loaded file 35
# Loaded file 36
# Loaded file 37
# Loaded file 38
# Loaded file 39
# Loaded file 40
# Loaded file 41
# Loaded file 42
# Loaded file 43
# Loaded file 44
# Loaded file 45
# Loaded file 46
# Loaded file 47
# Loaded file 48
# Loaded file 49
# Loaded file 50
# Loaded file 51
# Loaded file 52
# Loaded file 53
# Loaded file 54
# Loaded file 55
# Loaded file 56
# Loaded file 57
# Loaded file 58
# Loaded file 59
# Loaded file 60
# Loaded file 61
# Loaded file 62
# Loaded file 63
# Loaded file 64
# Loaded file 65
# Loaded file 66
# Loaded file 67
# Loaded file 68
# Loaded file 69
# Loaded file 70
# Loaded file 71
# Loaded file 72
# Loaded file 73
# Loaded file 74
# Loaded file 75
# Loaded file 76
# Loaded file 77
# Loaded file 78
# Loaded file 79
# Loaded file 80
# Loaded file 81
# Loaded file 82
# Loaded file 83
# Loaded file 84
# Loaded file 85
# Loaded file 86
# Loaded file 87
# Loaded file 88
# Loaded file 89
# Loaded file 90
# Loaded file 91
# Loaded file 92
# Loaded file 93
# Loaded file 94
# Loaded file 95
# Loaded file 96
# Loaded file 97
# Loaded file 98
# Loaded file 99
# Loaded file 100
# Loaded file 101
# Loaded file 102
# Loaded file 103
# Loaded file 104
# Loaded file 105
# Loaded file 106
# Loaded file 107
# Loaded file 108
# Loaded file 109
# Loaded file 110
# Loaded file 111
# Loaded file 112
# Loaded file 113
# Loaded file 114
# Loaded file 115
# Loaded file 116
# Loaded file 117
# Loaded file 118
# Loaded file 119
# Loaded file 120
# Loaded file 121
# Loaded file 122
# Loaded file 123
# Loaded file 124
# Loaded file 125
# Loaded file 126
# Loaded file 127
# Loaded file 128
# Loaded file 129
# Loaded file 130
# Loaded file 131
# Loaded file 132
# Loaded file 133
# Loaded file 134
# Loaded file 135
# Loaded file 136
# Loaded file 137
# Loaded file 138
# Loaded file 139
# Loaded file 140
# Loaded file 141
# Loaded file 142
# Loaded file 143
# Loaded file 144
# Loaded file 145
# Loaded file 146
# Loaded file 147
# Loaded file 148
# Loaded file 149
# Loaded file 150
# Loaded file 151
# Loaded file 152
# Loaded file 153
# Loaded file 154
# Loaded file 155
# Loaded file 156
# Loaded file 157
# Loaded file 158
# Loaded file 159
# Loaded file 160
# Loaded file 161
# Loaded file 162
# Loaded file 163
# Loaded file 164
# Loaded file 165
# Loaded file 166
# Loaded file 167
# Loaded file 168
# Loaded file 169
# Loaded file 170
# Loaded file 171
# Loaded file 172
# Loaded file 173
# Loaded file 174
# Loaded file 175
# Loaded file 176
# Loaded file 177
# Loaded file 178
# Loaded file 179
# Loaded file 180
# Loaded file 181
# Loaded file 182
# Loaded file 183
# Loaded file 184
# Loaded file 185
# Loaded file 186
# Loaded file 187
# Loaded file 188
# Loaded file 189
# Loaded file 190
# Loaded file 191
# Loaded file 192
# Loaded file 193
# Loaded file 194
# Loaded file 195
# Loaded file 196
# Loaded file 197
# Loaded file 198
# Loaded file 199
# Loaded file 200
# Loaded file 201
# Loaded file 202
# Loaded file 203
# Loaded file 204
# Loaded file 205
# Loaded file 206
# Loaded file 207
# Loaded file 208
# Loaded file 209
# Loaded file 210
# Loaded file 211
# Loaded file 212
# Loaded file 213
# Loaded file 214
# Loaded file 215
# Loaded file 216
# Loaded file 217
# Loaded file 218
# Loaded file 219
# Loaded file 220
# Loaded file 221
# Loaded file 222
# Loaded file 223
# Loaded file 224
# Loaded file 225
# Loaded file 226
# Loaded file 227
# Loaded file 228
# Loaded file 229
# Loaded file 230
# Loaded file 231
# Loaded file 232
# Loaded file 233
# Loaded file 234
# Loaded file 235
# Loaded file 236
# Loaded file 237
# Loaded file 238
# Loaded file 239
# Loaded file 240
# Loaded file 241
# Loaded file 242
# Loaded file 243
# Loaded file 244
# Loaded file 245
# Loaded file 246
# Loaded file 247
# Loaded file 248
# Loaded file 249
# Loaded file 250
# Loaded file 251
# Loaded file 252
# Loaded file 253
# Loaded file 254
# Loaded file 255
# Loaded file 256
# Loaded file 257
# Loaded file 258
# Loaded file 259
# Loaded file 260
# Loaded file 261
# Loaded file 262
# Loaded file 263
# Loaded file 264
# Loaded file 265
# Loaded file 266
# Loaded file 267
# Loaded file 268
# Loaded file 269
# Loaded file 270
# Loaded file 271
# Loaded file 272
# Loaded file 273
# Loaded file 274
# Loaded file 275
# Loaded file 276
# Loaded file 277
# Loaded file 278
# Loaded file 279
# Loaded file 280
# Loaded file 281
# Loaded file 282
# Loaded file 283
# Loaded file 284
# Loaded file 285
# Loaded file 286
# Loaded file 287
# Loaded file 288
# Loaded file 289
# Loaded file 290
# Loaded file 291
# Loaded file 292
# Loaded file 293
# Loaded file 294
# Loaded file 295
# Loaded file 296
# Loaded file 297
# Loaded file 298
# Loaded file 299
# Loaded file 300
# Loaded file 301
# Loaded file 302
# Loaded file 303
# Loaded file 304
# Loaded file 305
# Loaded file 306
# Loaded file 307
# Loaded file 308
# Loaded file 309
# Loaded file 310
# Loaded file 311
# Loaded file 312
# Loaded file 313
# Loaded file 314
# Loaded file 315
# Loaded file 316
# Loaded file 317
# Loaded file 318
# Loaded file 319
# Loaded file 320
# Loaded file 321
# Loaded file 322
# Loaded file 323
# Loaded file 324
# Loaded file 325
# Loaded file 326
# Loaded file 327
# Loaded file 328
# Loaded file 329
# Loaded file 330
# Loaded file 331
# Loaded file 332
# Loaded file 333
# Loaded file 334
# Loaded file 335
# Loaded file 336
# Loaded file 337
# Loaded file 338
# Loaded file 339
# Loaded file 340
# Loaded file 341
# Loaded file 342
# Loaded file 343
# Loaded file 344
# Loaded file 345
# Loaded file 346
# Loaded file 347
# Loaded file 348
# Loaded file 349
# Loaded file 350
# Loaded file 351
# Loaded file 352
# Loaded file 353
# Loaded file 354
# Loaded file 355
# Loaded file 356
# Loaded file 357
# Loaded file 358
# Loaded file 359
# Loaded file 360
# Loaded file 361
# Loaded file 362
# Loaded file 363
# Loaded file 364
# Loaded file 365
# Loaded file 366
# Loaded file 367
# Loaded file 368
# Loaded file 369
# Loaded file 370
# Loaded file 371
# Loaded file 372
# Loaded file 373
# Loaded file 374
# Loaded file 375
# Loaded file 376
# Loaded file 377
# Loaded file 378
# Loaded file 379
# Loaded file 380
# Loaded file 381
# Loaded file 382
# Loaded file 383
# Loaded file 384
# Loaded file 385
# Loaded file 386
# Loaded file 387
# Loaded file 388
# Loaded file 389
# Loaded file 390
# Loaded file 391
# Loaded file 392
# Loaded file 393
# Loaded file 394
# Loaded file 395
# Loaded file 396
# Loaded file 397
# Loaded file 398
# Loaded file 399
# Loaded file 400
# Loaded file 401
# Loaded file 402
# Loaded file 403
# Loaded file 404
# Loaded file 405
# Loaded file 406
# Loaded file 407
# Loaded file 408
# Loaded file 409
# Loaded file 410
# Loaded file 411
# Loaded file 412
# Loaded file 413
# Loaded file 414
# Loaded file 415
# Loaded file 416
# Loaded file 417
# Loaded file 418
# Loaded file 419
# Loaded file 420
# Loaded file 421
# Loaded file 422
# Loaded file 423
# Loaded file 424
# Loaded file 425
# Loaded file 426
# Loaded file 427
# Loaded file 428
# Loaded file 429
# Loaded file 430
# Loaded file 431
# Loaded file 432
# Loaded file 433
# Loaded file 434
# Loaded file 435
# Loaded file 436
# Loaded file 437
# Loaded file 438
# Loaded file 439
# Loaded file 440
# Loaded file 441
# Loaded file 442
# Loaded file 443
# Loaded file 444
# Loaded file 445
# Loaded file 446
# Loaded file 447
# Loaded file 448
# Loaded file 449
# Loaded file 450
# Loaded file 451
# Loaded file 452
# Loaded file 453
# Loaded file 454
# Loaded file 455
# Loaded file 456
# Loaded file 457
# Loaded file 458
# Loaded file 459
# Loaded file 460
# Loaded file 461
# Loaded file 462
# Loaded file 463
# Loaded file 464
# Loaded file 465
# Loaded file 466
# Loaded file 467
# Loaded file 468
# Loaded file 469
# Loaded file 470
# Loaded file 471
# Loaded file 472
# Loaded file 473
# Loaded file 474
# Loaded file 475
# Loaded file 476
# Loaded file 477
# Loaded file 478
# Loaded file 479
# Loaded file 480
# Loaded file 481
# Loaded file 482
# Loaded file 483
# Loaded file 484
# Loaded file 485
# Loaded file 486
# Loaded file 487
# Loaded file 488
# Loaded file 489
# Loaded file 490
# Loaded file 491
# Loaded file 492
# Loaded file 493
# Loaded file 494
# Loaded file 495
# Loaded file 496
# Loaded file 497
# Loaded file 498
# Loaded file 499
# Loaded file 500
# Loaded file 501
# Loaded file 502
# Loaded file 503
# Loaded file 504
# Loaded file 505
# Loaded file 506
# Loaded file 507
# Loaded file 508
# Loaded file 509
# Loaded file 510
# Loaded file 511
# Loaded file 512
# Loaded file 513
# Loaded file 514
# Loaded file 515
# Loaded file 516
# Loaded file 517
# Loaded file 518
# Loaded file 519
# Loaded file 520
# Loaded file 521
# Loaded file 522
# Loaded file 523
# Loaded file 524
# Loaded file 525
# Loaded file 526
# Loaded file 527
# Loaded file 528
# Loaded file 529
# Loaded file 530
# Loaded file 531
# Loaded file 532
# Loaded file 533
# Loaded file 534
# Loaded file 535
# Loaded file 536
# Loaded file 537
# Loaded file 538
# Loaded file 539
# Loaded file 540
# Loaded file 541
# Loaded file 542
# Loaded file 543
# Loaded file 544
# Loaded file 545
# Loaded file 546
# Loaded file 547
# Loaded file 548
# Loaded file 549
# Loaded file 550
# Loaded file 551
# Loaded file 552
# Loaded file 553
# Loaded file 554
# Loaded file 555
# Loaded file 556
# Loaded file 557
# Loaded file 558
# Loaded file 559
# Loaded file 560
# Loaded file 561
# Loaded file 562
# Loaded file 563
# Loaded file 564
# Loaded file 565
# Loaded file 566
# Loaded file 567
# Loaded file 568
# Loaded file 569
# Loaded file 570
# Loaded file 571
# Loaded file 572
# Loaded file 573
# Loaded file 574
# Loaded file 575
# Loaded file 576
# Loaded file 577
# Loaded file 578
# Loaded file 579
# Loaded file 580
# Loaded file 581
# Loaded file 582
# Loaded file 583
# Loaded file 584
# Loaded file 585
# Loaded file 586
# Loaded file 587
# Loaded file 588
# Loaded file 589
# Loaded file 590
# Loaded file 591
# Loaded file 592
# Loaded file 593
# Loaded file 594
# Loaded file 595
# Loaded file 596
# Loaded file 597
# Loaded file 598
# Loaded file 599
# Loaded file 600
# Loaded file 601
# Loaded file 602
# Loaded file 603
# Loaded file 604
# Loaded file 605
# Loaded file 606
# Loaded file 607
# Loaded file 608
# Loaded file 609
# Loaded file 610
# Loaded file 611
# Loaded file 612
# Loaded file 613
# Loaded file 614
# Loaded file 615
# Loaded file 616
# Loaded file 617
# Loaded file 618
# Loaded file 619
# Loaded file 620
# Loaded file 621
# Loaded file 622
# Loaded file 623
# Loaded file 624
# Loaded file 625
# Loaded file 626
# Loaded file 627
# Loaded file 628
# Loaded file 629
# Loaded file 630
# Loaded file 631
# Loaded file 632
# Loaded file 633
# Loaded file 634
# Loaded file 635
# Loaded file 636
# Loaded file 637
# Loaded file 638
# Loaded file 639
# Loaded file 640
# Loaded file 641
# Loaded file 642
# Loaded file 643
# Loaded file 644
# Loaded file 645
# Loaded file 646
# Loaded file 647
# Loaded file 648
# Loaded file 649
# Loaded file 650
# Loaded file 651
# Loaded file 652
# Loaded file 653
# Loaded file 654
# Loaded file 655
# Loaded file 656
# Loaded file 657
# Loaded file 658
# Loaded file 659
# Loaded file 660
# Loaded file 661
# Loaded file 662
# Loaded file 663
# Loaded file 664
# Loaded file 665
# Loaded file 666
# Loaded file 667
# Loaded file 668
# Loaded file 669
# Loaded file 670
# Loaded file 671
# Loaded file 672
# Loaded file 673
# Loaded file 674
# Loaded file 675
# Loaded file 676
# Loaded file 677
# Loaded file 678
# Loaded file 679
# Loaded file 680
# Loaded file 681
# Loaded file 682
# Loaded file 683
# Loaded file 684
# Loaded file 685
# Loaded file 686
# Loaded file 687
# Loaded file 688
# Loaded file 689
# Loaded file 690
# Loaded file 691
# Loaded file 692
# Loaded file 693
# Loaded file 694
# Loaded file 695
# Loaded file 696
# Loaded file 697
# Loaded file 698
# Loaded file 699
# Loaded file 700
# Loaded file 701
# Loaded file 702
# Loaded file 703
# Loaded file 704
# Loaded file 705
# Loaded file 706
# Loaded file 707
# Loaded file 708
# Loaded file 709
# Loaded file 710
# Loaded file 711
# Loaded file 712
# Loaded file 713
# Loaded file 714
# Loaded file 715
# Loaded file 716
# Loaded file 717
# Loaded file 718
# Loaded file 719
# Loaded file 720
# Loaded file 721
# Loaded file 722
# Loaded file 723
# Loaded file 724
# Loaded file 725
# Loaded file 726
# Loaded file 727
# Loaded file 728
# Loaded file 729
# Loaded file 730
# Loaded file 731
# Loaded file 732
# Loaded file 733
# Loaded file 734
# Loaded file 735
# Loaded file 736
# Loaded file 737
# Loaded file 738
# Loaded file 739
# Loaded file 740
# Loaded file 741
# Loaded file 742
# Loaded file 743
# Loaded file 744
# Loaded file 745
# Loaded file 746
# Loaded file 747
# Loaded file 748
# Loaded file 749
# Loaded file 750
# Loaded file 751
# Loaded file 752
# Loaded file 753
# Loaded file 754
# Loaded file 755
# Loaded file 756
# Loaded file 757
# Loaded file 758
# Loaded file 759
# Loaded file 760
# Loaded file 761
# Loaded file 762
# Loaded file 763
# Loaded file 764
# Loaded file 765
# Loaded file 766
# Loaded file 767
# Loaded file 768
# Loaded file 769
# Loaded file 770
# Loaded file 771
# Loaded file 772
# Loaded file 773
# Loaded file 774
# Loaded file 775
# Loaded file 776
# Loaded file 777
# Loaded file 778
# Loaded file 779
# Loaded file 780
# Loaded file 781
# Loaded file 782
# Loaded file 783
# Loaded file 784
# Loaded file 785
# Loaded file 786
# Loaded file 787
# Loaded file 788
# Loaded file 789
# Loaded file 790
# Loaded file 791
# Loaded file 792
# Loaded file 793
# Loaded file 794
# Loaded file 795
# Loaded file 796
# Loaded file 797
# Loaded file 798
# Loaded file 799
# Loaded file 800
# Loaded file 801
# Loaded file 802
# Loaded file 803
# Loaded file 804
# Loaded file 805
# Loaded file 806
# Loaded file 807
# Loaded file 808
# Loaded file 809
# Loaded file 810
# Loaded file 811
# Loaded file 812
# Loaded file 813
# Loaded file 814
# Loaded file 815
# Loaded file 816
# Loaded file 817
# Loaded file 818
# Loaded file 819
# Loaded file 820
# Loaded file 821
# Loaded file 822
# Loaded file 823
# Loaded file 824
# Loaded file 825
# Loaded file 826
# Loaded file 827
# Loaded file 828
# Loaded file 829
# Loaded file 830
# Loaded file 831
# Loaded file 832
# Loaded file 833
# Loaded file 834
# Loaded file 835
# Loaded file 836
# Loaded file 837
# Loaded file 838
# Loaded file 839
# Loaded file 840
# Loaded file 841
# Loaded file 842
# Loaded file 843
# Loaded file 844
# Loaded file 845
# Loaded file 846
# Loaded file 847
# Loaded file 848
# Loaded file 849
# Loaded file 850
# Loaded file 851
# Loaded file 852
# Loaded file 853
# Loaded file 854
# Loaded file 855
# Loaded file 856
# Loaded file 857
# Loaded file 858
# Loaded file 859
# Loaded file 860
# Loaded file 861
# Loaded file 862
# Loaded file 863
# Loaded file 864
# Loaded file 865
# Loaded file 866
# Loaded file 867
# Loaded file 868
# Loaded file 869
# Loaded file 870
# Loaded file 871
# Loaded file 872
# Loaded file 873
# Loaded file 874
# Loaded file 875
# Loaded file 876
# Loaded file 877
# Loaded file 878
# Loaded file 879
# Loaded file 880
# Loaded file 881
# Loaded file 882
# Loaded file 883
# Loaded file 884
# Loaded file 885
# Loaded file 886
# Loaded file 887
# Loaded file 888
# Loaded file 889
# Loaded file 890
# Loaded file 891
# Loaded file 892
# Loaded file 893
# Loaded file 894
# Loaded file 895
# Loaded file 896
# Loaded file 897
# Loaded file 898
# Loaded file 899
# Loaded file 900
# Loaded file 901
# Loaded file 902
# Loaded file 903
# Loaded file 904
# Loaded file 905
# Loaded file 906
# Loaded file 907
# Loaded file 908
# Loaded file 909
# Loaded file 910
# Loaded file 911
# Loaded file 912
# Loaded file 913
# Loaded file 914
# Loaded file 915
# Loaded file 916
# Loaded file 917
# Loaded file 918
# Loaded file 919
# Loaded file 920
# Loaded file 921
# Loaded file 922
# Loaded file 923
# Loaded file 924
# Loaded file 925
# Loaded file 926
# Loaded file 927
# Loaded file 928
# Loaded file 929
# Loaded file 930
# Loaded file 931
# Loaded file 932
# Loaded file 933
# Loaded file 934
# Loaded file 935
# Loaded file 936
# Loaded file 937
# Loaded file 938
# Loaded file 939
# Loaded file 940
# Loaded file 941
# Loaded file 942
# Loaded file 943
# Loaded file 944
# Loaded file 945
# Loaded file 946
# Loaded file 947
# Loaded file 948
# Loaded file 949
# Loaded file 950
# Loaded file 951
# Loaded file 952
# Loaded file 953
# Loaded file 954
# Loaded file 955
# Loaded file 956
# Loaded file 957
# Loaded file 958
# Loaded file 959
# Loaded file 960
# Loaded file 961
# Loaded file 962
# Loaded file 963
# Loaded file 964
# Loaded file 965
# Loaded file 966
# Loaded file 967
# Loaded file 968
# Loaded file 969
# Loaded file 970
# Loaded file 971
# Loaded file 972
# Loaded file 973
# Loaded file 974
# Loaded file 975
# Loaded file 976
# Loaded file 977
# Loaded file 978
# Loaded file 979
# Loaded file 980
# Loaded file 981
# Loaded file 982
# Loaded file 983
# Loaded file 984
# Loaded file 985
# Loaded file 986
# Loaded file 987
# Loaded file 988
# Loaded file 989
# Loaded file 990
# Loaded file 991
# Loaded file 992
# Loaded file 993
# Loaded file 994
# Loaded file 995
# Loaded file 996
# Loaded file 997
# Loaded file 998
# Loaded file 999
# Loaded file 1000
# Loaded file 1001
# Loaded file 1002
# Loaded file 1003
# Loaded file 1004
# Loaded file 1005
# Loaded file 1006
# Loaded file 1007
# Loaded file 1008
# Loaded file 1009
# Loaded file 1010
# Loaded file 1011
# Loaded file 1012
# Loaded file 1013
# Loaded file 1014
# Loaded file 1015
# Loaded file 1016
# Loaded file 1017
# Loaded file 1018
# Loaded file 1019
# Loaded file 1020
# Loaded file 1021
# Loaded file 1022
# Loaded file 1023
# Loaded file 1024
# Loaded file 1025
# Loaded file 1026
# Loaded file 1027
# Loaded file 1028
# Loaded file 1029
# Loaded file 1030
# Loaded file 1031
# Loaded file 1032
# Loaded file 1033
# Loaded file 1034
# Loaded file 1035
# Loaded file 1036
# Loaded file 1037
# Loaded file 1038
# Loaded file 1039
# Loaded file 1040
# Loaded file 1041
# Loaded file 1042
# Loaded file 1043
# Loaded file 1044
# Loaded file 1045
# Loaded file 1046
# Loaded file 1047
# Loaded file 1048
# Loaded file 1049
# Loaded file 1050
# Loaded file 1051
# Loaded file 1052
# Loaded file 1053
# Loaded file 1054
# Loaded file 1055
# Loaded file 1056
# Loaded file 1057
# Loaded file 1058
# Loaded file 1059
# Loaded file 1060
# Loaded file 1061
# Loaded file 1062
# Loaded file 1063
# Loaded file 1064
# Loaded file 1065
# Loaded file 1066
# Loaded file 1067
# Loaded file 1068
# Loaded file 1069
# Loaded file 1070
# Loaded file 1071
# Loaded file 1072
# Loaded file 1073
# Loaded file 1074
# Loaded file 1075
# Loaded file 1076
# Loaded file 1077
# Loaded file 1078
# Loaded file 1079
# Loaded file 1080
# Loaded file 1081
# Loaded file 1082
# Loaded file 1083
# Loaded file 1084
# Loaded file 1085
# Loaded file 1086
# Loaded file 1087
# Loaded file 1088
# Loaded file 1089
# Loaded file 1090
# Loaded file 1091
# Loaded file 1092
# Loaded file 1093
# Loaded file 1094
# Loaded file 1095
# Loaded file 1096
# Loaded file 1097
# Loaded file 1098
# Loaded file 1099
# Loaded file 1100
# Loaded file 1101
# Loaded file 1102
# Loaded file 1103
# Loaded file 1104
# Loaded file 1105
# Loaded file 1106
# Loaded file 1107
# Loaded file 1108
# Loaded file 1109
# Loaded file 1110
# Loaded file 1111
# Loaded file 1112
# Loaded file 1113
# Loaded file 1114
# Loaded file 1115
# Loaded file 1116
# Loaded file 1117
# Loaded file 1118
# Loaded file 1119
# Loaded file 1120
# Loaded file 1121
# Loaded file 1122
# Loaded file 1123
# Loaded file 1124
# Loaded file 1125
# Loaded file 1126
# Loaded file 1127
# Loaded file 1128
# Loaded file 1129
# Loaded file 1130
# Loaded file 1131
# Loaded file 1132
# Loaded file 1133
# Loaded file 1134
# Loaded file 1135
# Loaded file 1136
# Loaded file 1137
# Loaded file 1138
# Loaded file 1139
# Loaded file 1140
# Loaded file 1141
# Loaded file 1142
# Loaded file 1143
# Loaded file 1144
# Loaded file 1145
# Loaded file 1146
# Loaded file 1147
# Loaded file 1148
# Loaded file 1149
# Loaded file 1150
# Loaded file 1151
# Loaded file 1152
# Loaded file 1153
# Loaded file 1154
# Loaded file 1155
# Loaded file 1156
# Loaded file 1157
# Loaded file 1158
# Loaded file 1159
# Loaded file 1160
# Loaded file 1161
# Loaded file 1162
# Loaded file 1163
# Loaded file 1164
# Loaded file 1165
# Loaded file 1166
# Loaded file 1167
# Loaded file 1168
# Loaded file 1169
# Loaded file 1170
# Loaded file 1171
# Loaded file 1172
# Loaded file 1173
# Loaded file 1174
# Loaded file 1175
# Loaded file 1176
# Loaded file 1177
# Loaded file 1178
# Loaded file 1179
# Loaded file 1180
# Loaded file 1181
# Loaded file 1182
# Loaded file 1183
# Loaded file 1184
# Loaded file 1185
# Loaded file 1186
# Loaded file 1187
# Loaded file 1188
# Loaded file 1189
# Loaded file 1190
# Loaded file 1191
# Loaded file 1192
# Loaded file 1193
# Loaded file 1194
# Loaded file 1195
# Loaded file 1196
# Loaded file 1197
# Loaded file 1198
# Loaded file 1199
# Loaded file 1200
# Loaded file 1201
# Loaded file 1202
# Loaded file 1203
# Loaded file 1204
# Loaded file 1205
# Loaded file 1206
# Loaded file 1207
# Loaded file 1208
# Loaded file 1209
# Loaded file 1210
# Loaded file 1211
# Loaded file 1212
# Loaded file 1213
# Loaded file 1214
# Loaded file 1215
# Loaded file 1216
# Loaded file 1217
# Loaded file 1218
# Loaded file 1219
# Loaded file 1220
# Loaded file 1221
# Loaded file 1222
# Loaded file 1223
# Loaded file 1224
# Loaded file 1225
# Loaded file 1226
# Loaded file 1227
# Loaded file 1228
# Loaded file 1229
# Loaded file 1230
# Loaded file 1231
# Loaded file 1232
# Loaded file 1233
# Loaded file 1234
# Loaded file 1235
# Loaded file 1236
# Loaded file 1237
# Loaded file 1238
# Loaded file 1239
# Loaded file 1240
# Loaded file 1241
# Loaded file 1242
# Loaded file 1243
# Loaded file 1244
# Loaded file 1245
# Loaded file 1246
# Loaded file 1247
# Loaded file 1248
# Loaded file 1249
# Loaded file 1250
# Loaded file 1251
# Loaded file 1252
# Loaded file 1253
# Loaded file 1254
# Loaded file 1255
# Loaded file 1256
# Loaded file 1257
# Loaded file 1258
# Loaded file 1259
# Loaded file 1260
# Loaded file 1261
# Loaded file 1262
# Loaded file 1263
# Loaded file 1264
# Loaded file 1265
# Loaded file 1266
# Loaded file 1267
# Loaded file 1268
# Loaded file 1269
# Loaded file 1270
# Loaded file 1271
# Loaded file 1272
# Loaded file 1273
# Loaded file 1274
# Loaded file 1275
# Loaded file 1276
# Loaded file 1277
# Loaded file 1278
# Loaded file 1279
# Loaded file 1280
# Loaded file 1281
# Loaded file 1282
# Loaded file 1283
# Loaded file 1284
# Loaded file 1285
# Loaded file 1286
# Loaded file 1287
# Loaded file 1288
# Loaded file 1289
# Loaded file 1290
# Loaded file 1291
# Loaded file 1292
# Loaded file 1293
# Loaded file 1294
# Loaded file 1295
# Loaded file 1296
# Loaded file 1297
# Loaded file 1298
# Loaded file 1299
# Loaded file 1300
# Loaded file 1301
# Loaded file 1302
# Loaded file 1303
# Loaded file 1304
# Loaded file 1305
# Loaded file 1306
# Loaded file 1307
# Loaded file 1308
# Loaded file 1309
# Loaded file 1310
# Loaded file 1311
# Loaded file 1312
# Loaded file 1313
# Loaded file 1314
# Loaded file 1315
# Loaded file 1316
# Loaded file 1317
# Loaded file 1318
# Loaded file 1319
# Loaded file 1320
# Loaded file 1321
# Loaded file 1322
# Loaded file 1323
# Loaded file 1324
# Loaded file 1325
# Loaded file 1326
# Loaded file 1327
# Loaded file 1328
# Loaded file 1329
# Loaded file 1330
# Loaded file 1331
# Loaded file 1332
# Loaded file 1333
# Loaded file 1334
# Loaded file 1335
# Loaded file 1336
# Loaded file 1337
# Loaded file 1338
# Loaded file 1339
# Loaded file 1340
# Loaded file 1341
# Loaded file 1342
# Loaded file 1343
# Loaded file 1344
# Loaded file 1345
# Loaded file 1346
# Loaded file 1347
# Loaded file 1348
# Loaded file 1349
# Loaded file 1350
# Loaded file 1351
# Loaded file 1352
# Loaded file 1353
# Loaded file 1354
# Loaded file 1355
# Loaded file 1356
# Loaded file 1357
# Loaded file 1358
# Loaded file 1359
# Loaded file 1360
# Loaded file 1361
# Loaded file 1362
# Loaded file 1363
# Loaded file 1364
# Loaded file 1365
# Loaded file 1366
# Loaded file 1367
# Loaded file 1368
# Loaded file 1369
# Loaded file 1370
# Loaded file 1371
# Loaded file 1372
# Loaded file 1373
# Loaded file 1374
# Loaded file 1375
# Loaded file 1376
# Loaded file 1377
# Loaded file 1378
# Loaded file 1379
# Loaded file 1380
# Loaded file 1381
# Loaded file 1382
# Loaded file 1383
# Loaded file 1384
# Loaded file 1385
# Loaded file 1386
# Loaded file 1387
# Loaded file 1388
# Loaded file 1389
# Loaded file 1390
# Loaded file 1391
# Loaded file 1392
# Loaded file 1393
# Loaded file 1394
# Loaded file 1395
# Loaded file 1396
# Loaded file 1397
# Loaded file 1398
# Loaded file 1399
# Loaded file 1400
# Loaded file 1401
# Loaded file 1402
# Loaded file 1403
# Loaded file 1404
# Loaded file 1405
# Loaded file 1406
# Loaded file 1407
# Loaded file 1408
# Loaded file 1409
# Loaded file 1410
# Loaded file 1411
# Loaded file 1412
# Loaded file 1413
# Loaded file 1414
# Loaded file 1415
# Loaded file 1416
# Loaded file 1417
# Loaded file 1418
# Loaded file 1419
# Loaded file 1420
# Loaded file 1421
# Loaded file 1422
# Loaded file 1423
# Loaded file 1424
# Loaded file 1425
# Loaded file 1426
# Loaded file 1427
# Loaded file 1428
# Loaded file 1429
# Loaded file 1430
# Loaded file 1431
# Loaded file 1432
# Loaded file 1433
# Loaded file 1434
# Loaded file 1435
# Loaded file 1436
# Loaded file 1437
# Loaded file 1438
# Loaded file 1439
# Loaded file 1440
# Loaded file 1441
# Loaded file 1442
# Loaded file 1443
# Loaded file 1444
# Loaded file 1445
# Loaded file 1446
# Loaded file 1447
# Loaded file 1448
# Loaded file 1449
# Loaded file 1450
# Loaded file 1451
# Loaded file 1452
# Loaded file 1453
# Loaded file 1454
# Loaded file 1455
# Loaded file 1456
# Loaded file 1457
# Loaded file 1458
# Loaded file 1459
# Loaded file 1460
# Loaded file 1461
# Loaded file 1462
# Loaded file 1463
# Loaded file 1464
# Loaded file 1465
# Loaded file 1466
# Loaded file 1467
# Loaded file 1468
# Loaded file 1469
# Loaded file 1470
# Loaded file 1471
# Loaded file 1472
# Loaded file 1473
# Loaded file 1474
# Loaded file 1475
# Loaded file 1476
# Loaded file 1477
# Loaded file 1478
# Loaded file 1479
# Loaded file 1480
# Loaded file 1481
# Loaded file 1482
# Loaded file 1483
# Loaded file 1484
# Loaded file 1485
# Loaded file 1486
# Loaded file 1487
# Loaded file 1488
# Loaded file 1489
# Loaded file 1490
# Loaded file 1491
# Loaded file 1492
# Loaded file 1493
# Loaded file 1494
# Loaded file 1495
# Loaded file 1496
# Loaded file 1497
# Loaded file 1498
# Loaded file 1499
# Loaded file 1500
# Loaded file 1501
# Loaded file 1502
# Loaded file 1503
# Loaded file 1504
# Loaded file 1505
# Loaded file 1506
# Loaded file 1507
# Loaded file 1508
# Loaded file 1509
# Loaded file 1510
# Loaded file 1511
# Loaded file 1512
# Loaded file 1513
# Loaded file 1514
# Loaded file 1515
# Loaded file 1516
# Loaded file 1517
# Loaded file 1518
# Loaded file 1519
# Loaded file 1520
# Loaded file 1521
# Loaded file 1522
# Loaded file 1523
# Loaded file 1524
# Loaded file 1525
# Loaded file 1526
# Loaded file 1527
# Loaded file 1528
# Loaded file 1529
# Loaded file 1530
# Loaded file 1531
# Loaded file 1532
# Loaded file 1533
# Loaded file 1534
# Loaded file 1535
# Loaded file 1536
# Loaded file 1537
# Loaded file 1538
# Loaded file 1539
# Loaded file 1540
# Loaded file 1541
# Loaded file 1542
# Loaded file 1543
# Loaded file 1544
# Loaded file 1545
# Loaded file 1546
# Loaded file 1547
# Loaded file 1548
# Loaded file 1549
# Loaded file 1550
# Loaded file 1551
# Loaded file 1552
# Loaded file 1553
# Loaded file 1554
# Loaded file 1555
# Loaded file 1556
# Loaded file 1557
# Loaded file 1558
# Loaded file 1559
# Loaded file 1560
# Loaded file 1561
# Loaded file 1562
# Loaded file 1563
# Loaded file 1564
# Loaded file 1565
# Loaded file 1566
# Loaded file 1567
# Loaded file 1568
# Loaded file 1569
# Loaded file 1570
# Loaded file 1571
# Loaded file 1572
# Loaded file 1573
# Loaded file 1574
# Loaded file 1575
# Loaded file 1576
# Loaded file 1577
# Loaded file 1578
# Loaded file 1579
# Loaded file 1580
# Loaded file 1581
# Loaded file 1582
# Loaded file 1583
# Loaded file 1584
# Loaded file 1585
# Loaded file 1586
# Loaded file 1587
# Loaded file 1588
# Loaded file 1589
# Loaded file 1590
# Loaded file 1591
# Loaded file 1592
# Loaded file 1593
# Loaded file 1594
# Loaded file 1595
# Loaded file 1596
# Loaded file 1597
# Loaded file 1598
# Loaded file 1599
# Loaded file 1600
# Loaded file 1601
# Loaded file 1602
# Loaded file 1603
# Loaded file 1604
# Loaded file 1605
# Loaded file 1606
# Loaded file 1607
# Loaded file 1608
# Loaded file 1609
# Loaded file 1610
# Loaded file 1611
# Loaded file 1612
# Loaded file 1613
# Loaded file 1614
# Loaded file 1615
# Loaded file 1616
# Loaded file 1617
# Loaded file 1618
# Loaded file 1619
# Loaded file 1620
# Loaded file 1621
# Loaded file 1622
# Loaded file 1623
# Loaded file 1624
# Loaded file 1625
# Loaded file 1626
# Loaded file 1627
# Loaded file 1628
# Loaded file 1629
# Loaded file 1630
# Loaded file 1631
# Loaded file 1632
# Loaded file 1633
# Loaded file 1634
# Loaded file 1635
# Loaded file 1636
# Loaded file 1637
# Loaded file 1638
# Loaded file 1639
# Loaded file 1640
# Loaded file 1641
# Loaded file 1642
# Loaded file 1643
# Loaded file 1644
# Loaded file 1645
# Loaded file 1646
# Loaded file 1647
# Loaded file 1648
# Loaded file 1649
# Loaded file 1650
# Loaded file 1651
# Loaded file 1652
# Loaded file 1653
# Loaded file 1654
# Loaded file 1655
# Loaded file 1656
# Loaded file 1657
# Loaded file 1658
# Loaded file 1659
# Loaded file 1660
# Loaded file 1661
# Loaded file 1662
# Loaded file 1663
# Loaded file 1664
# Loaded file 1665
# Loaded file 1666
# Loaded file 1667
# Loaded file 1668
# Loaded file 1669
# Loaded file 1670
# Loaded file 1671
# Loaded file 1672
# Loaded file 1673
# Loaded file 1674
# Loaded file 1675
# Loaded file 1676
# Loaded file 1677
# Loaded file 1678
# Loaded file 1679
# Loaded file 1680
# Loaded file 1681
# Loaded file 1682
# Loaded file 1683
# Loaded file 1684
# Loaded file 1685
# Loaded file 1686
# Loaded file 1687
# Loaded file 1688
# Loaded file 1689
# Loaded file 1690
# Loaded file 1691
# Loaded file 1692
# Loaded file 1693
# Loaded file 1694
# Loaded file 1695
# Loaded file 1696
# Loaded file 1697
# Loaded file 1698
# Loaded file 1699
# Loaded file 1700
# Loaded file 1701
# Loaded file 1702
# Loaded file 1703
# Loaded file 1704
# Loaded file 1705
# Loaded file 1706
# Loaded file 1707
# Loaded file 1708
# Loaded file 1709
# Loaded file 1710
# Loaded file 1711
# Loaded file 1712
# Loaded file 1713
# Loaded file 1714
# Loaded file 1715
# Loaded file 1716
# Loaded file 1717
# Loaded file 1718
# Loaded file 1719
# Loaded file 1720
# Loaded file 1721
# Loaded file 1722
# Loaded file 1723
# Loaded file 1724
# Loaded file 1725
# Loaded file 1726
# Loaded file 1727
# Loaded file 1728
# Loaded file 1729
# Loaded file 1730
# Loaded file 1731
# Loaded file 1732
# Loaded file 1733
# Loaded file 1734
# Loaded file 1735
# Loaded file 1736
# Loaded file 1737
# Loaded file 1738
# Loaded file 1739
# Loaded file 1740
# Loaded file 1741
# Loaded file 1742
# Loaded file 1743
# Loaded file 1744
# Loaded file 1745
# Loaded file 1746
# Loaded file 1747
# Loaded file 1748
# Loaded file 1749
# Loaded file 1750
# Loaded file 1751
# Loaded file 1752
# Loaded file 1753
# Loaded file 1754
# Loaded file 1755
# Loaded file 1756
# Loaded file 1757
# Loaded file 1758
# Loaded file 1759
# Loaded file 1760
# Loaded file 1761
# Loaded file 1762
# Loaded file 1763
# Loaded file 1764
# Loaded file 1765
# Loaded file 1766
# Loaded file 1767
# Loaded file 1768
# Loaded file 1769
# Loaded file 1770
# Loaded file 1771
# Loaded file 1772
# Loaded file 1773
# Loaded file 1774
# Loaded file 1775
# Loaded file 1776
# Loaded file 1777
# Loaded file 1778
# Loaded file 1779
# Loaded file 1780
# Loaded file 1781
# Loaded file 1782
# Loaded file 1783
# Loaded file 1784
# Loaded file 1785
# Loaded file 1786
# Loaded file 1787
# Loaded file 1788
# Loaded file 1789
# Loaded file 1790
# Loaded file 1791
# Loaded file 1792
# Loaded file 1793
# Loaded file 1794
# Loaded file 1795
# Loaded file 1796
# Loaded file 1797
# Loaded file 1798
# Loaded file 1799
# Loaded file 1800
# Loaded file 1801
# Loaded file 1802
# Loaded file 1803
# Loaded file 1804
# Loaded file 1805
# Loaded file 1806
# Loaded file 1807
# Loaded file 1808
# Loaded file 1809
# Loaded file 1810
# Loaded file 1811
# Loaded file 1812
# Loaded file 1813
# Loaded file 1814
# Loaded file 1815
# Loaded file 1816
# Loaded file 1817
# Loaded file 1818
# Loaded file 1819
# Loaded file 1820
# Loaded file 1821
# Loaded file 1822
# Loaded file 1823
# Loaded file 1824
# Loaded file 1825
# Loaded file 1826
# Loaded file 1827
# Loaded file 1828
# Loaded file 1829
# Loaded file 1830
# Loaded file 1831
# Loaded file 1832
# Loaded file 1833
# Loaded file 1834
# Loaded file 1835
# Loaded file 1836
# Loaded file 1837
# Loaded file 1838
# Loaded file 1839
# Loaded file 1840
# Loaded file 1841
# Loaded file 1842
# Loaded file 1843
# Loaded file 1844
# Loaded file 1845
# Loaded file 1846
# Loaded file 1847
# Loaded file 1848
# Loaded file 1849
# Loaded file 1850
# Loaded file 1851
# Loaded file 1852
# Loaded file 1853
# Loaded file 1854
# Loaded file 1855
# Loaded file 1856
# Loaded file 1857
# Loaded file 1858
# Loaded file 1859
# Loaded file 1860
# Loaded file 1861
# Loaded file 1862
# Loaded file 1863
# Loaded file 1864
# Loaded file 1865
# Loaded file 1866
# Loaded file 1867
# Loaded file 1868
# Loaded file 1869
# Loaded file 1870
# Loaded file 1871
# Loaded file 1872
# Loaded file 1873
# Loaded file 1874
# Loaded file 1875
# Loaded file 1876
# Loaded file 1877
# Loaded file 1878
# Loaded file 1879
# Loaded file 1880
# Loaded file 1881
# Loaded file 1882
# Loaded file 1883
# Loaded file 1884
# Loaded file 1885
# Loaded file 1886
# Loaded file 1887
# Loaded file 1888
# Loaded file 1889
# Loaded file 1890
# Loaded file 1891
# Loaded file 1892
# Loaded file 1893
# Loaded file 1894
# Loaded file 1895
# Loaded file 1896
# Loaded file 1897
# Loaded file 1898
# Loaded file 1899
# Loaded file 1900
# Loaded file 1901
# Loaded file 1902
# Loaded file 1903
# Loaded file 1904
# Loaded file 1905
# Loaded file 1906
# Loaded file 1907
# Loaded file 1908
# Loaded file 1909
# Loaded file 1910
# Loaded file 1911
# Loaded file 1912
# Loaded file 1913
# Loaded file 1914
# Loaded file 1915
# Loaded file 1916
# Loaded file 1917
# Loaded file 1918
# Loaded file 1919
# Loaded file 1920
# Loaded file 1921
# Loaded file 1922
# Loaded file 1923
# Loaded file 1924
# Loaded file 1925
# Loaded file 1926
# Loaded file 1927
# Loaded file 1928
# Loaded file 1929
# Loaded file 1930
# Loaded file 1931
# Loaded file 1932
# Loaded file 1933
# Loaded file 1934
# Loaded file 1935
# Loaded file 1936
# Loaded file 1937
# Loaded file 1938
# Loaded file 1939
# Loaded file 1940
# Loaded file 1941
# Loaded file 1942
# Loaded file 1943
# Loaded file 1944
# Loaded file 1945
# Loaded file 1946
# Loaded file 1947
# Loaded file 1948
# Loaded file 1949
# Loaded file 1950
# Loaded file 1951
# Loaded file 1952
# Loaded file 1953
# Loaded file 1954
# Loaded file 1955
# Loaded file 1956
# Loaded file 1957
# Loaded file 1958
# Loaded file 1959
# Loaded file 1960
# Loaded file 1961
# Loaded file 1962
# Loaded file 1963
# Loaded file 1964
# Loaded file 1965
# Loaded file 1966
# Loaded file 1967
# Loaded file 1968
# Loaded file 1969
# Loaded file 1970
# Loaded file 1971
# Loaded file 1972
# Loaded file 1973
# Loaded file 1974
# Loaded file 1975
# Loaded file 1976
# Loaded file 1977
# Loaded file 1978
# Loaded file 1979
# Loaded file 1980
# Loaded file 1981
# Loaded file 1982
# Loaded file 1983
# Loaded file 1984
# Loaded file 1985
# Loaded file 1986
# Loaded file 1987
# Loaded file 1988
# Loaded file 1989
# Loaded file 1990
# Loaded file 1991
# Loaded file 1992
# Loaded file 1993
# Loaded file 1994
# Loaded file 1995
# Loaded file 1996
# Loaded file 1997
# Loaded file 1998
# Loaded file 1999
# Loaded file 2000
# Loaded file 2001
# Loaded file 2002
# Loaded file 2003
# Loaded file 2004
# Loaded file 2005
# Loaded file 2006
# Loaded file 2007
# Loaded file 2008
# Loaded file 2009
# Loaded file 2010
# Loaded file 2011
# Loaded file 2012
# Loaded file 2013
# Loaded file 2014
# Loaded file 2015
# Loaded file 2016
# Loaded file 2017
# Loaded file 2018
# Loaded file 2019
# Loaded file 2020
# Loaded file 2021
# Loaded file 2022
# Loaded file 2023
# Loaded file 2024
# Loaded file 2025
# Loaded file 2026
# Loaded file 2027
# Loaded file 2028
# Loaded file 2029
# Loaded file 2030
# Loaded file 2031
# Loaded file 2032
# Loaded file 2033
# Loaded file 2034
# Loaded file 2035
# Loaded file 2036
# Loaded file 2037
# Loaded file 2038
# Loaded file 2039
# Loaded file 2040
# Loaded file 2041
# Loaded file 2042
# Loaded file 2043
# Loaded file 2044
# Loaded file 2045
# Loaded file 2046
# Loaded file 2047
# Loaded file 2048
# Loaded file 2049
# Loaded file 2050
# Loaded file 2051
# Loaded file 2052
# Loaded file 2053
# Loaded file 2054
# Loaded file 2055
# Loaded file 2056
# Loaded file 2057
# Loaded file 2058
# Loaded file 2059
# Loaded file 2060
# Loaded file 2061
# Loaded file 2062
# Loaded file 2063
# Loaded file 2064
# Loaded file 2065
# Loaded file 2066
# Loaded file 2067
# Loaded file 2068
# Loaded file 2069
# Loaded file 2070
# Loaded file 2071
# Loaded file 2072
# Loaded file 2073
# Loaded file 2074
# Loaded file 2075
# Loaded file 2076
# Loaded file 2077
# Loaded file 2078
# Loaded file 2079
# Loaded file 2080
# Loaded file 2081
# Loaded file 2082
# Loaded file 2083
# Loaded file 2084
# Loaded file 2085
# Loaded file 2086
# Loaded file 2087
# Loaded file 2088
# Loaded file 2089
# Loaded file 2090
# Loaded file 2091
# Loaded file 2092
# Loaded file 2093
# Loaded file 2094
# Loaded file 2095
# Loaded file 2096
# Loaded file 2097
# Loaded file 2098
# Loaded file 2099
# Loaded file 2100
# Loaded file 2101
# Loaded file 2102
# Loaded file 2103
# Loaded file 2104
# Loaded file 2105
# Loaded file 2106
# Loaded file 2107
# Loaded file 2108
# Loaded file 2109
# Loaded file 2110
# Loaded file 2111
# Loaded file 2112
# Loaded file 2113
# Loaded file 2114
# Loaded file 2115
# Loaded file 2116
# Loaded file 2117
# Loaded file 2118
# Loaded file 2119
# Loaded file 2120
# Loaded file 2121
# Loaded file 2122
# Loaded file 2123
# Loaded file 2124
# Loaded file 2125
# Loaded file 2126
# Loaded file 2127
# Loaded file 2128
# Loaded file 2129
# Loaded file 2130
# Loaded file 2131
# Loaded file 2132
# Loaded file 2133
# Loaded file 2134
# Loaded file 2135
# Loaded file 2136
# Loaded file 2137
# Loaded file 2138
# Loaded file 2139
# Loaded file 2140
# Loaded file 2141
# Loaded file 2142
# Loaded file 2143
# Loaded file 2144
# Loaded file 2145
# Loaded file 2146
# Loaded file 2147
# Loaded file 2148
# Loaded file 2149
# Loaded file 2150
# Loaded file 2151
# Loaded file 2152
# Loaded file 2153
# Loaded file 2154
# Loaded file 2155
# Loaded file 2156
# Loaded file 2157
# Loaded file 2158
# Loaded file 2159
# Loaded file 2160
# Loaded file 2161
# Loaded file 2162
# Loaded file 2163
# Loaded file 2164
# Loaded file 2165
# Loaded file 2166
# Loaded file 2167
# Loaded file 2168
# Loaded file 2169
# Loaded file 2170
# Loaded file 2171
# Loaded file 2172
# Loaded file 2173
# Loaded file 2174
# Loaded file 2175
# Loaded file 2176
# Loaded file 2177
# Loaded file 2178
# Loaded file 2179
# Loaded file 2180
# Loaded file 2181
# Loaded file 2182
# Loaded file 2183
# Loaded file 2184
# Loaded file 2185
# Loaded file 2186
# Loaded file 2187
# Loaded file 2188
# Loaded file 2189
# Loaded file 2190
# Loaded file 2191
# Loaded file 2192
# Loaded file 2193
# Loaded file 2194
# Loaded file 2195
# Loaded file 2196
# Loaded file 2197
# Loaded file 2198
# Loaded file 2199
# Loaded file 2200
# Loaded file 2201
# Loaded file 2202
# Loaded file 2203
# Loaded file 2204
# Loaded file 2205
# Loaded file 2206
# Loaded file 2207
# Loaded file 2208
# Loaded file 2209
# Loaded file 2210
# Loaded file 2211
# Loaded file 2212
# Loaded file 2213
# Loaded file 2214
# Loaded file 2215
# Loaded file 2216
# Loaded file 2217
# Loaded file 2218
# Loaded file 2219
# Loaded file 2220
# Loaded file 2221
# Loaded file 2222
# Loaded file 2223
# Loaded file 2224
# Loaded file 2225
# Loaded file 2226
# Loaded file 2227
# Loaded file 2228
# Loaded file 2229
# Loaded file 2230
# Loaded file 2231
# Loaded file 2232
# Loaded file 2233
# Loaded file 2234
# Loaded file 2235
# Loaded file 2236
# Loaded file 2237
# Loaded file 2238
# Loaded file 2239
# Loaded file 2240
# Loaded file 2241
# Loaded file 2242
# Loaded file 2243
# Loaded file 2244
# Loaded file 2245
# Loaded file 2246
# Loaded file 2247
# Loaded file 2248
# Loaded file 2249
# Loaded file 2250
# Loaded file 2251
# Loaded file 2252
# Loaded file 2253
# Loaded file 2254
# Loaded file 2255
# Loaded file 2256
# Loaded file 2257
# Loaded file 2258
# Loaded file 2259
# Loaded file 2260
# Loaded file 2261
# Loaded file 2262
# Loaded file 2263
# Loaded file 2264
# Loaded file 2265
# Loaded file 2266
# Loaded file 2267
# Loaded file 2268
# Loaded file 2269
# Loaded file 2270
# Loaded file 2271
# Loaded file 2272
# Loaded file 2273
# Loaded file 2274
# Loaded file 2275
# Loaded file 2276
# Loaded file 2277
# Loaded file 2278
# Loaded file 2279
# Loaded file 2280
# Loaded file 2281
# Loaded file 2282
# Loaded file 2283
# Loaded file 2284
# Loaded file 2285
# Loaded file 2286
# Loaded file 2287
# Loaded file 2288
# Loaded file 2289
# Loaded file 2290
# Loaded file 2291
# Loaded file 2292
# Loaded file 2293
# Loaded file 2294
# Loaded file 2295
# Loaded file 2296
# Loaded file 2297
# Loaded file 2298
# Loaded file 2299
# Loaded file 2300
# Loaded file 2301
# Loaded file 2302
# Loaded file 2303
# Loaded file 2304
# Loaded file 2305
# Loaded file 2306
# Loaded file 2307
# Loaded file 2308
# Loaded file 2309
# Loaded file 2310
# Loaded file 2311
# Loaded file 2312
# Loaded file 2313
# Loaded file 2314
# Loaded file 2315
# Loaded file 2316
# Loaded file 2317
# Loaded file 2318
# Loaded file 2319
# Loaded file 2320
# Loaded file 2321
# Loaded file 2322
# Loaded file 2323
# Loaded file 2324
# Loaded file 2325
# Loaded file 2326
# Loaded file 2327
# Loaded file 2328
# Loaded file 2329
# Loaded file 2330
# Loaded file 2331
# Loaded file 2332
# Loaded file 2333
# Loaded file 2334
# Loaded file 2335
# Loaded file 2336
# Loaded file 2337
# Loaded file 2338
# Loaded file 2339
# Loaded file 2340
# Loaded file 2341
# Loaded file 2342
# Loaded file 2343
# Loaded file 2344
# Loaded file 2345
# Loaded file 2346
# Loaded file 2347
# Loaded file 2348
# Loaded file 2349
# Loaded file 2350
# Loaded file 2351
# Loaded file 2352
# Loaded file 2353
# Loaded file 2354
# Loaded file 2355
# Loaded file 2356
# Loaded file 2357
# Loaded file 2358
# Loaded file 2359
# Loaded file 2360
# Loaded file 2361
# Loaded file 2362
# Loaded file 2363
# Loaded file 2364
# Loaded file 2365
# Loaded file 2366
# Loaded file 2367
# Loaded file 2368
# Loaded file 2369
# Loaded file 2370
# Loaded file 2371
# Loaded file 2372
# Loaded file 2373
# Loaded file 2374
# Loaded file 2375
# Loaded file 2376
# Loaded file 2377
# Loaded file 2378
# Loaded file 2379
# Loaded file 2380
# Loaded file 2381
# Loaded file 2382
# Loaded file 2383
# Loaded file 2384
# Loaded file 2385
# Loaded file 2386
# Loaded file 2387
# Loaded file 2388
# Loaded file 2389
# Loaded file 2390
# Loaded file 2391
# Loaded file 2392
# Loaded file 2393
# Loaded file 2394
# Loaded file 2395
# Loaded file 2396
# Loaded file 2397
# Loaded file 2398
# Loaded file 2399
# Loaded file 2400
# Loaded file 2401
# Loaded file 2402
# Loaded file 2403
# Loaded file 2404
# Loaded file 2405
# Loaded file 2406
# Loaded file 2407
# Loaded file 2408
# Loaded file 2409
# Loaded file 2410
# Loaded file 2411
# Loaded file 2412
# Loaded file 2413
# Loaded file 2414
# Loaded file 2415
# Missing file 2416 dict_keys(['WJetsToLNu_HT-800To1200_TuneCP5_13TeV-madgraphMLM-pythia8'])
# Loaded file 2417
# Loaded file 2418
# Loaded file 2419
# Loaded file 2420
# Loaded file 2421
# Loaded file 2422
# Loaded file 2423
# Loaded file 2424
# Loaded file 2425
# Loaded file 2426
# Loaded file 2427
# Loaded file 2428
# Loaded file 2429
# Loaded file 2430
# Loaded file 2431
# Loaded file 2432
# Loaded file 2433
# Loaded file 2434
# Loaded file 2435
# Loaded file 2436
# Loaded file 2437
# Loaded file 2438
# Loaded file 2439
# Loaded file 2440
# Loaded file 2441
# Loaded file 2442
# Loaded file 2443
# Loaded file 2444
# Loaded file 2445
# Loaded file 2446
# Loaded file 2447
# Loaded file 2448
# Loaded file 2449
# Loaded file 2450
# Loaded file 2451
# Loaded file 2452
# Loaded file 2453
# Loaded file 2454
# Loaded file 2455
# Loaded file 2456
# Loaded file 2457
# Loaded file 2458
# Loaded file 2459
# Loaded file 2460
# Loaded file 2461
# Loaded file 2462
# Loaded file 2463
# Loaded file 2464
# Loaded file 2465
# Loaded file 2466
# Loaded file 2467
# Loaded file 2468
# Loaded file 2469
# Loaded file 2470
# Loaded file 2471
# Loaded file 2472
# Loaded file 2473
# Loaded file 2474
# Loaded file 2475
# Loaded file 2476
# Loaded file 2477
# Loaded file 2478
# Loaded file 2479
# Loaded file 2480
# Loaded file 2481
# Loaded file 2482
# Loaded file 2483
# Loaded file 2484
# Loaded file 2485
# Loaded file 2486
# Loaded file 2487
# Loaded file 2488
# Loaded file 2489
# Loaded file 2490
# Loaded file 2491
# Loaded file 2492
# Loaded file 2493
# Loaded file 2494
# Loaded file 2495
# Loaded file 2496
# Loaded file 2497
# Loaded file 2498
# Loaded file 2499
# Loaded file 2500
# Loaded file 2501
# Loaded file 2502
# Loaded file 2503
# Loaded file 2504
# Loaded file 2505
# Loaded file 2506
# Loaded file 2507
# Loaded file 2508
# Loaded file 2509
# Loaded file 2510
# Loaded file 2511
# Loaded file 2512
# Loaded file 2513
# Loaded file 2514
# Loaded file 2515
# Loaded file 2516
# Loaded file 2517
# Loaded file 2518
# Loaded file 2519
# Loaded file 2520
# Loaded file 2521
# Loaded file 2522
# Loaded file 2523
# Loaded file 2524
# Loaded file 2525
# Loaded file 2526
# Loaded file 2527
# Loaded file 2528
# Loaded file 2529
# Loaded file 2530
# Loaded file 2531
# Loaded file 2532
# Loaded file 2533
# Loaded file 2534
# Loaded file 2535
# Loaded file 2536
# Loaded file 2537
# Loaded file 2538
# Loaded file 2539
# Loaded file 2540
# Loaded file 2541
# Loaded file 2542
# Loaded file 2543
# Loaded file 2544
# Loaded file 2545
# Loaded file 2546
# Loaded file 2547
# Loaded file 2548
# Loaded file 2549
# Loaded file 2550
# Loaded file 2551
# Loaded file 2552
# Loaded file 2553
# Loaded file 2554
# Loaded file 2555
# Loaded file 2556
# Loaded file 2557
# Loaded file 2558
# Loaded file 2559
# Loaded file 2560
# Loaded file 2561
# Loaded file 2562
# Loaded file 2563
# Loaded file 2564
# Loaded file 2565
# Loaded file 2566
# Loaded file 2567
# Loaded file 2568
# Loaded file 2569
# Loaded file 2570
# Loaded file 2571
# Loaded file 2572
# Loaded file 2573
# Loaded file 2574
# Loaded file 2575
# Loaded file 2576
# Loaded file 2577
# Loaded file 2578
# Loaded file 2579
# Loaded file 2580
# Loaded file 2581
# Loaded file 2582
# Loaded file 2583
# Loaded file 2584
# Loaded file 2585
# Loaded file 2586
# Loaded file 2587
# Loaded file 2588
# Loaded file 2589
# Loaded file 2590
# Loaded file 2591
# Loaded file 2592
# Loaded file 2593
# Loaded file 2594
# Loaded file 2595
# Loaded file 2596
# Loaded file 2597
# Loaded file 2598
# Loaded file 2599
# Loaded file 2600
# Loaded file 2601
# Loaded file 2602
# Loaded file 2603
# Loaded file 2604
# Loaded file 2605
# Loaded file 2606
# Loaded file 2607
# Loaded file 2608
# Loaded file 2609
# Loaded file 2610
# Loaded file 2611
# Loaded file 2612
# Loaded file 2613
# Loaded file 2614
# Loaded file 2615
# Loaded file 2616
# Loaded file 2617
# Loaded file 2618
# Loaded file 2619
# Loaded file 2620
# Loaded file 2621
# Loaded file 2622
# Loaded file 2623
# Loaded file 2624
# Loaded file 2625
# Loaded file 2626
# Loaded file 2627
# Loaded file 2628
# Loaded file 2629
# Loaded file 2630
# Loaded file 2631
# Loaded file 2632
# Loaded file 2633
# Loaded file 2634
# Loaded file 2635
# Loaded file 2636
# Loaded file 2637
# Loaded file 2638
# Loaded file 2639
# Loaded file 2640
# Loaded file 2641
# Loaded file 2642
# Loaded file 2643
# Loaded file 2644
# Loaded file 2645
# Loaded file 2646
# Loaded file 2647
# Loaded file 2648
# Loaded file 2649
# Loaded file 2650
# Loaded file 2651
# Loaded file 2652
# Loaded file 2653
# Loaded file 2654
# Loaded file 2655
# Loaded file 2656
# Loaded file 2657
# Loaded file 2658
# Loaded file 2659
# Loaded file 2660
# Loaded file 2661
# Loaded file 2662
# Loaded file 2663
# Loaded file 2664
# Loaded file 2665
# Loaded file 2666
# Loaded file 2667
# Loaded file 2668
# Loaded file 2669
# Loaded file 2670
# Loaded file 2671
# Loaded file 2672
# Loaded file 2673
# Loaded file 2674
# Loaded file 2675
# Loaded file 2676
# Loaded file 2677
# Loaded file 2678
# Loaded file 2679
# Loaded file 2680
# Loaded file 2681
# Loaded file 2682
# Loaded file 2683
# Loaded file 2684
# Loaded file 2685
# Loaded file 2686
# Loaded file 2687
# Loaded file 2688
# Loaded file 2689
# Loaded file 2690
# Loaded file 2691
# Loaded file 2692
# Loaded file 2693
# Loaded file 2694
# Loaded file 2695
# Loaded file 2696
# Loaded file 2697
# Loaded file 2698
# Loaded file 2699
# Loaded file 2700
# Loaded file 2701
# Loaded file 2702
# Loaded file 2703
# Loaded file 2704
# Loaded file 2705
# Loaded file 2706
# Loaded file 2707
# Loaded file 2708
# Loaded file 2709
# Loaded file 2710
# Loaded file 2711
# Loaded file 2712
# Loaded file 2713
# Loaded file 2714
# Loaded file 2715
# Loaded file 2716
# Loaded file 2717
# Loaded file 2718
# Loaded file 2719
# Loaded file 2720
# Loaded file 2721
# Loaded file 2722
# Loaded file 2723
# Loaded file 2724
# Loaded file 2725
# Loaded file 2726
# Loaded file 2727
# Loaded file 2728
# Loaded file 2729
# Loaded file 2730
# Loaded file 2731
# Loaded file 2732
# Loaded file 2733
# Loaded file 2734
# Loaded file 2735
# Loaded file 2736
# Loaded file 2737
# Loaded file 2738
# Loaded file 2739
# Loaded file 2740
# Loaded file 2741
# Loaded file 2742
# Loaded file 2743
# Loaded file 2744
# Loaded file 2745
# Loaded file 2746
# Loaded file 2747
# Loaded file 2748
# Loaded file 2749
# Loaded file 2750
# Loaded file 2751
# Loaded file 2752
# Loaded file 2753
# Loaded file 2754
# Loaded file 2755
# Loaded file 2756
# Loaded file 2757
# Loaded file 2758
# Loaded file 2759
# Loaded file 2760
# Loaded file 2761
# Loaded file 2762
# Loaded file 2763
# Loaded file 2764
# Loaded file 2765
# Loaded file 2766
# Loaded file 2767
# Loaded file 2768
# Loaded file 2769
# Loaded file 2770
# Loaded file 2771
# Loaded file 2772
# Loaded file 2773
# Loaded file 2774
# Loaded file 2775
# Loaded file 2776
# Loaded file 2777
# Loaded file 2778
# Loaded file 2779
# Loaded file 2780
# Loaded file 2781
# Loaded file 2782
# Loaded file 2783
# Loaded file 2784
# Loaded file 2785
# Loaded file 2786
# Loaded file 2787
# Loaded file 2788
# Loaded file 2789
# Loaded file 2790
# Loaded file 2791
# Loaded file 2792
# Loaded file 2793
# Loaded file 2794
# Loaded file 2795
# Loaded file 2796
# Loaded file 2797
# Loaded file 2798
# Loaded file 2799
# Loaded file 2800
# Loaded file 2801
# Loaded file 2802
# Loaded file 2803
# Loaded file 2804
# Loaded file 2805
# Loaded file 2806
# Loaded file 2807
# Loaded file 2808
# Loaded file 2809
# Loaded file 2810
# Loaded file 2811
# Loaded file 2812
# Loaded file 2813
# Loaded file 2814
# Loaded file 2815
# Loaded file 2816
# Loaded file 2817
# Loaded file 2818
# Loaded file 2819
# Loaded file 2820
# Loaded file 2821
# Loaded file 2822
# Loaded file 2823
# Loaded file 2824
# Loaded file 2825
# Loaded file 2826
# Loaded file 2827
# Loaded file 2828
# Loaded file 2829
# Loaded file 2830
# Loaded file 2831
# Loaded file 2832
# Loaded file 2833
# Loaded file 2834
# Loaded file 2835
# Loaded file 2836
# Loaded file 2837
# Loaded file 2838
# Loaded file 2839
# Loaded file 2840
# Loaded file 2841
# Loaded file 2842
# Loaded file 2843
# Loaded file 2844
# Loaded file 2845
# Loaded file 2846
# Loaded file 2847
# Loaded file 2848
# Loaded file 2849
# Loaded file 2850
# Loaded file 2851
# Loaded file 2852
# Loaded file 2853
# Loaded file 2854
# Loaded file 2855
# Loaded file 2856
# Loaded file 2857
# Loaded file 2858
# Loaded file 2859
# Loaded file 2860
# Loaded file 2861
# Loaded file 2862
# Loaded file 2863
# Loaded file 2864
# Loaded file 2865
# Loaded file 2866
# Loaded file 2867
# Loaded file 2868
# Loaded file 2869
# Loaded file 2870
# Loaded file 2871
# Loaded file 2872
# Loaded file 2873
# Loaded file 2874
# Loaded file 2875
# Loaded file 2876
# Loaded file 2877
# Loaded file 2878
# Loaded file 2879
# Loaded file 2880
# Loaded file 2881
# Loaded file 2882
# Loaded file 2883
# Loaded file 2884
# Loaded file 2885
# Loaded file 2886
# Loaded file 2887
# Loaded file 2888
# Loaded file 2889
# Loaded file 2890
# Loaded file 2891
# Loaded file 2892
# Loaded file 2893
# Loaded file 2894
# Loaded file 2895
# Loaded file 2896
# Loaded file 2897
# Loaded file 2898
# Loaded file 2899
# Loaded file 2900
# Loaded file 2901
# Loaded file 2902
# Loaded file 2903
# Loaded file 2904
# Loaded file 2905
# Loaded file 2906
# Loaded file 2907
# Loaded file 2908
# Loaded file 2909
# Loaded file 2910
# Loaded file 2911
# Loaded file 2912
# Loaded file 2913
# Loaded file 2914
# Loaded file 2915
# Loaded file 2916
# Loaded file 2917
# Loaded file 2918
# Loaded file 2919
# Loaded file 2920
# Loaded file 2921
# Loaded file 2922
# Loaded file 2923
# Loaded file 2924
# Loaded file 2925
# Loaded file 2926
# Loaded file 2927
# Loaded file 2928
# Loaded file 2929
# Loaded file 2930
# Loaded file 2931
# Loaded file 2932
# Loaded file 2933
# Loaded file 2934
# Loaded file 2935
# Loaded file 2936
# Loaded file 2937
# Loaded file 2938
# Loaded file 2939
# Loaded file 2940
# Loaded file 2941
# Loaded file 2942
# Loaded file 2943
# Loaded file 2944
# Loaded file 2945
# Loaded file 2946
# Loaded file 2947
# Loaded file 2948
# Loaded file 2949
# Loaded file 2950
# Loaded file 2951
# Loaded file 2952
# Loaded file 2953
# Loaded file 2954
# Loaded file 2955
# Loaded file 2956
# Loaded file 2957
# Loaded file 2958
# Loaded file 2959
# Loaded file 2960
# Loaded file 2961
# Loaded file 2962
# Loaded file 2963
# Loaded file 2964
# Loaded file 2965
# Loaded file 2966
# Loaded file 2967
# Loaded file 2968
# Loaded file 2969
# Loaded file 2970
# Loaded file 2971
# Loaded file 2972
# Loaded file 2973
# Loaded file 2974
# Loaded file 2975
# Loaded file 2976
# Loaded file 2977
# Loaded file 2978
# Loaded file 2979
# Loaded file 2980
# Loaded file 2981
# Loaded file 2982
# Loaded file 2983
# Loaded file 2984
# Loaded file 2985
# Loaded file 2986
# Loaded file 2987
# Loaded file 2988
# Loaded file 2989
# Loaded file 2990
# Loaded file 2991
# Loaded file 2992
# Loaded file 2993
# Loaded file 2994
# Loaded file 2995
# Loaded file 2996
# Loaded file 2997
# Loaded file 2998
# Loaded file 2999
# Loaded file 3000
# Loaded file 3001
# Loaded file 3002
# Loaded file 3003
# Loaded file 3004
# Loaded file 3005
# Loaded file 3006
# Loaded file 3007
# Loaded file 3008
# Loaded file 3009
# Loaded file 3010
# Loaded file 3011
# Loaded file 3012
# Loaded file 3013
# Loaded file 3014
# Loaded file 3015
# Loaded file 3016
# Loaded file 3017
# Loaded file 3018
# Loaded file 3019
# Loaded file 3020
# Loaded file 3021
# Loaded file 3022
# Loaded file 3023
# Loaded file 3024
# Loaded file 3025
# Loaded file 3026
# Loaded file 3027
# Loaded file 3028
# Loaded file 3029
# Loaded file 3030
# Loaded file 3031
# Loaded file 3032
# Loaded file 3033
# Loaded file 3034
# Loaded file 3035
# Loaded file 3036
# Loaded file 3037
# Loaded file 3038
# Loaded file 3039
# Loaded file 3040
# Loaded file 3041
# Loaded file 3042
# Loaded file 3043
# Loaded file 3044
# Loaded file 3045
# Loaded file 3046
# Loaded file 3047
# Loaded file 3048
# Loaded file 3049
# Loaded file 3050
# Loaded file 3051
# Loaded file 3052
# Loaded file 3053
# Loaded file 3054
# Loaded file 3055
# Loaded file 3056
# Loaded file 3057
# Loaded file 3058
# Loaded file 3059
# Loaded file 3060
# Loaded file 3061
# Loaded file 3062
# Loaded file 3063
# Loaded file 3064
# Loaded file 3065
# Loaded file 3066
# Loaded file 3067
# Loaded file 3068
# Loaded file 3069
# Loaded file 3070
# Loaded file 3071
# Loaded file 3072
# Loaded file 3073
# Loaded file 3074
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-03e565df6fca> in <module>
#      11         filename = '/myeosdir/vbf-category/outfiles/'+year+'_'+str(n)+'.coffea'
#      12         if os.path.isfile(filename):
# ---> 13             out = util.load(filename)
#      14             outsum.add(out)
#      15             print('Loaded file '+str(n))
#
# /opt/conda/lib/python3.8/site-packages/coffea/util.py in load(filename)
#      20     """Load a coffea file from disk"""
#      21     with lz4.frame.open(filename) as fin:
# ---> 22         output = cloudpickle.load(fin)
#      23     return output
#      24
#
# /opt/conda/lib/python3.8/site-packages/lz4/frame/__init__.py in read(self, size)
#     633         """
#     634         self._check_can_read()
# --> 635         return self._buffer.read(size)
#     636
#     637     def read1(self, size=-1):
#
# /opt/conda/lib/python3.8/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /opt/conda/lib/python3.8/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# /opt/conda/lib/python3.8/site-packages/lz4/frame/__init__.py in decompress(self, data, max_length)
#     392             data = self._unconsumed_data + data
#     393
# --> 394         decompressed, bytes_read, eoframe = decompress_chunk(
#     395             self._context,
#     396             data,
#
# MemoryError:

# %%
cutflow = pickle.load(open('pickles/'+str(year)+'_cutflow.pkl','rb'))
cutflow = cutflow.sum('genflavor').integrate('region','muoncontrol')

# %%
cutflow.integrate('process','muondata').values()

# %%
cutflow.integrate('process','ttbar').values()

# %%
df1 = pd.DataFrame([])

df1['QCD'] = cutflow.values()[('QCD',)]
df1['Wjets'] = cutflow.values()[('Wjets',)]
df1['Zjets'] = cutflow.values()[('Zjets',)]
df1['VV'] = cutflow.values()[('VV',)]
df1['ttbar'] = cutflow.values()[('ttbar',)]
df1['singlet'] = cutflow.values()[('singlet',)]
df1['data'] = cutflow.values()[('muondata',)]

df1 = df1[1:10].astype('int')
df1.index = ['Jet kinematics','Jet ID','Jet $N_2^\text{DDT}$','b-tag','No e/tau','One muon','Dphi(muon,AK8)','AK4jets','DeepDoubleB']
df1.to_latex(buf=year+'/cutflow-muoncr.tex')

# %%
deta_cut = 2
mjj_cut = 500

# %%
templates = pickle.load(open('pickles/'+str(year)+'_templates.pkl','rb'))
templates = templates.integrate('systematic','nominal')
muonkin = pickle.load(open('pickles/'+str(year)+'_muonkin.pkl','rb'))
mujetkin = pickle.load(open('pickles/'+str(year)+'_mujetkin.pkl','rb'))

# %%
h = templates.integrate('region', 'muoncontrol').sum('pt1').integrate('ddb1',int_range=slice(0,0.89)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_msd1_fail',year+" muon CR, DDB fail")
h = templates.integrate('region', 'muoncontrol').sum('pt1').integrate('ddb1',int_range=slice(0.89,1)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_msd1_pass',year+" muon CR, DDB pass")
h = templates.integrate('region', 'muoncontrol').sum('ddb1','pt1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_msd1',year+" muon CR")

# %%
h = templates.integrate('region', 'muoncontrol').sum('ddb1','msd1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_pt1',year+" muon CR")

# %%
h = mujetkin.integrate('region', 'muoncontrol').sum('ddb1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_msd1',year+" muon CR")

# %%
h = mujetkin.integrate('region', 'muoncontrol').sum('eta1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_ddb1',year+" muon CR")

# %%
h = muonkin.integrate('region', 'muoncontrol').sum('etamu',).integrate('ddb1',int_range=slice(0.89,1)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_ptmu_pass',year+" muon CR, DDB pass")
h = muonkin.integrate('region', 'muoncontrol').sum('etamu').integrate('ddb1',int_range=slice(0,0.89)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_ptmu_fail',year+" muon CR, DDB fail")
h = muonkin.integrate('region', 'muoncontrol').sum('etamu','ddb1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_ptmu',year+" muon CR")

# %%
h = muonkin.integrate('region', 'muoncontrol').sum('ptmu').integrate('ddb1',int_range=slice(0.89,1)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_etamu_pass',year+" muon CR, DDB pass")
h = muonkin.integrate('region', 'muoncontrol').sum('ptmu').integrate('ddb1',int_range=slice(0,0.89)).integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_etamu_fail',year+" muon CR, DDB fail")
h = muonkin.integrate('region', 'muoncontrol').sum('ptmu','ddb1').integrate('deta',int_range=slice(deta_cut,7)).integrate('mjj',int_range=slice(mjj_cut,4000))
plot_datamc_muoncr(h,year+'/muCR_etamu',year+" muon CR")
