# %%
import os, subprocess
import json
import uproot3
import awkward as ak
import numpy as np
from coffea import processor, util, hist
import pickle

from plotter import *

# %%
lumis = {}
lumis['2016'] = 35.9
lumis['2017'] = 41.5
lumis['2018'] = 59.9

with open('xsec.json') as f:
  xs = json.load(f)

with open('pmap.json') as f:
  pmap = json.load(f)

systematics = ['nominal',
               'jet_triggerUp','jet_triggerDown',
               'btagWeightUp','btagWeightDown','btagEffStatUp','btagEffStatDown',
               'UESUp','UESDown','JESUp','JESDown','JERUp','JERDown',
              ]

# %%
year = '2017'
nfiles = len(subprocess.getoutput("ls infiles-split/"+year+"*.json").split())
outsum = processor.dict_accumulator()

# %%
# Read the histogram from the pickle file
picklename = 'pickles/'+year+'_templates.pkl'
templates = pickle.load(open(picklename,'rb')).integrate('region','signal')

# %%
# check intergrals
templates.sum('pt1','msd1','msd2','ddb1').integrate('systematic','nominal')
# Out:
# <Hist (process) instance at 0x7fb6c5f9db80>

# %%
h = templates.sum('pt1','ddb1','msd2')
mc = ['QCD','Wjets','Zjets','ttbar','singlet','VV','ggF','VBF','ZH','WH','ttH']

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'JES', year+' '+p+' JES', year+'/syst_JES/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'JER',year+' '+p+' JER',year+'/syst_JER/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'btagWeight',year+' '+p+' btagWeight',year+'/syst_btagWeight/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'btagEffStat',year+' '+p+' btagEffStat',year+'/syst_btagEffStat/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'UES',year+' '+p+' UES',year+'/syst_UES/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])

# %%
for p in mc:
    plot_syst(h.integrate('process',p),'jet_trigger',year+' '+p+' jet_trigger',year+'/syst_jet_trigger/'+p)
# Out:
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:96: RuntimeWarning: invalid value encountered in double_scalars
#   up_ratio = np.array([up_array[i]/nom_array[i] for i in range(len(nom_array))])
# /srv/vh-category/plotter.py:97: RuntimeWarning: invalid value encountered in double_scalars
#   do_ratio = np.array([do_array[i]/nom_array[i] for i in range(len(nom_array))])
